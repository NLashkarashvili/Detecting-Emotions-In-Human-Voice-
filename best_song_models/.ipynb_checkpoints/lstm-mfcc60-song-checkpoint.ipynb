# %%
import numpy as np
import pandas as pd
import librosa
import os, json, math
import scipy.io.wavfile as wavf
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold
import tensorflow as tf
from tensorflow.keras.layers import LSTM, Flatten, Dense, Dropout, BatchNormalization, Activation
import warnings
warnings.filterwarnings("ignore")
from tqdm import tqdm

# %%
#SETTINGS
sample_r = 22050
seconds = 4.3
n_samples = int(sample_r * seconds)
num_mfcc = 60
n_fft = 2048
hop_length = 512
num_segments = 1

# %% [markdown]
# * Train/Val/Test -> 80/10/10
# * Song Data

# %%
#load speech data
data = pd.read_csv('../input/ravdess-data/RAVDESS.csv')
data_speech = data[data['type']=='song']

# %%
data_speech.drop(columns=['type'], inplace=True)

# %%
data_speech.head()
# Out:
#       Unnamed: 0  actor   male  \
# 1440           0      2  False
# 1441           0      2  False
# 1442           0      2  False
# 1443           0      2  False
# 1444           0      2  False
#
#                                             folder_name    label
# 1440  ../input/ravdess-speech-song/aaudio_Song_Actor...    angry
# 1441  ../input/ravdess-speech-song/aaudio_Song_Actor...  fearful
# 1442  ../input/ravdess-speech-song/aaudio_Song_Actor...    happy
# 1443  ../input/ravdess-speech-song/aaudio_Song_Actor...    happy
# 1444  ../input/ravdess-speech-song/aaudio_Song_Actor...      sad

# %%
data_speech.drop(columns = 'Unnamed: 0', inplace=True)

# %%
data_speech['male'] = data_speech['male'].astype(np.int8)

# %%
label_encoder = LabelEncoder()
label_encoder.fit(data_speech['label'].unique())
data_speech['label'] = label_encoder.transform(data_speech['label'])
data_speech.head()
# Out:
#       actor  male                                        folder_name  label
# 1440      2     0  ../input/ravdess-speech-song/aaudio_Song_Actor...      0
# 1441      2     0  ../input/ravdess-speech-song/aaudio_Song_Actor...      2
# 1442      2     0  ../input/ravdess-speech-song/aaudio_Song_Actor...      3
# 1443      2     0  ../input/ravdess-speech-song/aaudio_Song_Actor...      3
# 1444      2     0  ../input/ravdess-speech-song/aaudio_Song_Actor...      5

# %%
train_speech = data_speech[data_speech['actor']<=20]
val_speech = data_speech[(data_speech['actor']>20) & (data_speech['actor']<=22)]
test_speech = data_speech[data_speech['actor']>22]

# %%
train_folders = train_speech['folder_name'].values
train_labels = train_speech['label'].values
test_folders = test_speech['folder_name'].values
test_labels = test_speech['label'].values
val_folders = val_speech['folder_name'].values
val_labels = val_speech['label'].values

# %%
def generate_mfcc(filenames, labels, num_mfcc=num_mfcc, n_fft=n_fft, 
                  hop_length=hop_length, num_segments=num_segments):
    #save file
    data = {
        "labels": [],
        "mfcc": []
    }

    samples_per_segment = int(n_samples / num_segments)
    num_mfcc_vectors_per_segment = math.ceil(n_samples / hop_length)
    for i, (filename, label) in tqdm(enumerate(zip(filenames, labels))):
        #load audio file       
        signal, sample_rate = librosa.load(filename, sr=sample_r)
        signal, _ = librosa.effects.trim(signal, top_db = 30)
        if signal.shape[0] < n_samples:
            signal = np.pad(signal, n_samples - signal.shape[0])
        if signal.shape[0] > n_samples:
            signal = signal[:n_samples]
        # process segments
        for segment in range(num_segments):
            # calculate start and finish of the sample
            start = samples_per_segment * segment
            finish = start + samples_per_segment
            # extract mfcc
            mfcc = librosa.feature.mfcc(signal[start:finish], sample_rate, n_mfcc=num_mfcc, n_fft=n_fft, hop_length=hop_length)
            mfcc = mfcc.T
            #store mfccs and labels
            if len(mfcc) == num_mfcc_vectors_per_segment:
                data["mfcc"].append(mfcc.tolist())
                data["labels"].append(label)
    return data

# %%
train_speech_mfcc = generate_mfcc(filenames=train_folders, labels=train_labels)
val_speech_mfcc = generate_mfcc(filenames=val_folders, labels=val_labels)
test_speech_mfcc = generate_mfcc(filenames=test_folders, labels=test_labels)
# Out:
# 836it [04:15,  3.27it/s]
# 88it [00:27,  3.19it/s]
# 88it [00:27,  3.25it/s]

# %%
X_train, X_valid, X_test = train_speech_mfcc['mfcc'], val_speech_mfcc['mfcc'], test_speech_mfcc['mfcc']
X_train, X_valid, X_test = np.array(X_train), np.array(X_valid), np.array(X_test)
Y_train, Y_valid, Y_test = train_speech_mfcc['labels'], val_speech_mfcc['labels'], test_speech_mfcc['labels']
Y_train, Y_valid, Y_test = np.array(Y_train), np.array(Y_valid), np.array(Y_test)

# %%
X_train.shape
# Out:
# (836, 186, 60)

# %%
input_shape = (X_train.shape[1], X_train.shape[2])

# %%
input_mfcc = tf.keras.Input(shape=input_shape)
lstm1 = LSTM(256, input_shape = (None, input_shape[0], input_shape[1]),return_sequences = True, 
                 name = 'lstm_layer1', dropout=0.2)(input_mfcc)
flatten = Flatten()(lstm1)
pred = Dense(6, input_shape = (None, 256), activation='softmax')(flatten)

# %%
model = tf.keras.Model(
    inputs=[input_mfcc],
    outputs=pred,
    name='lstm_model-mfcc{mfcc}'.format(mfcc=num_mfcc)
)

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0005),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model_path_val_loss = "lstm_models_n_mfcc{num_mfcc:04d}-val-loss".format(num_mfcc=num_mfcc)
checkpoint_path_loss = model_path_val_loss + "-{epoch:04d}.ckpt"
checkpoint_dir_loss = os.path.dirname(checkpoint_path_loss)
# !mkdir $model_path_val_loss

# %%
model.save_weights(checkpoint_path_loss.format(epoch=0))

checkpoint_loss = tf.keras.callbacks.ModelCheckpoint(checkpoint_path_loss, monitor='val_loss', verbose=1,
        save_weights_only=True, save_best_only=True, mode='auto')

# %%
model.summary()
# Out:
# Model: "lstm_model-mfcc60"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 186, 60)]         0
# _________________________________________________________________
# lstm_layer1 (LSTM)           (None, 186, 256)          324608
# _________________________________________________________________
# flatten (Flatten)            (None, 47616)             0
# _________________________________________________________________
# dense (Dense)                (None, 6)                 285702
# =================================================================
# Total params: 610,310
# Trainable params: 610,310
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train, Y_train, validation_data=(X_valid, Y_valid), 
                    batch_size=32, epochs=100, callbacks=[checkpoint_loss])
# Out:
# Epoch 1/100
# 27/27 [==============================] - 15s 480ms/step - loss: 3.2533 - accuracy: 0.2267 - val_loss: 1.7068 - val_accuracy: 0.3636
#
# Epoch 00001: val_loss improved from inf to 1.70684, saving model to lstm_models_n_mfcc0060-val-loss-0001.ckpt
# Epoch 2/100
# 27/27 [==============================] - 12s 442ms/step - loss: 1.0988 - accuracy: 0.5816 - val_loss: 1.2663 - val_accuracy: 0.5114
#
# Epoch 00002: val_loss improved from 1.70684 to 1.26629, saving model to lstm_models_n_mfcc0060-val-loss-0002.ckpt
# Epoch 3/100
# 27/27 [==============================] - 12s 452ms/step - loss: 0.6317 - accuracy: 0.7612 - val_loss: 1.5694 - val_accuracy: 0.4091
#
# Epoch 00003: val_loss did not improve from 1.26629
# Epoch 4/100
# 27/27 [==============================] - 12s 447ms/step - loss: 0.3980 - accuracy: 0.8545 - val_loss: 1.0633 - val_accuracy: 0.5795
#
# Epoch 00004: val_loss improved from 1.26629 to 1.06327, saving model to lstm_models_n_mfcc0060-val-loss-0004.ckpt
# Epoch 5/100
# 27/27 [==============================] - 12s 456ms/step - loss: 0.2817 - accuracy: 0.9091 - val_loss: 1.0041 - val_accuracy: 0.6250
#
# Epoch 00005: val_loss improved from 1.06327 to 1.00408, saving model to lstm_models_n_mfcc0060-val-loss-0005.ckpt
# Epoch 6/100
# 27/27 [==============================] - 13s 486ms/step - loss: 0.2375 - accuracy: 0.9264 - val_loss: 1.3218 - val_accuracy: 0.4659
#
# Epoch 00006: val_loss did not improve from 1.00408
# Epoch 7/100
# 27/27 [==============================] - 12s 444ms/step - loss: 0.2332 - accuracy: 0.9188 - val_loss: 1.1873 - val_accuracy: 0.5341
#
# Epoch 00007: val_loss did not improve from 1.00408
# Epoch 8/100
# 27/27 [==============================] - 12s 452ms/step - loss: 0.1667 - accuracy: 0.9403 - val_loss: 1.2484 - val_accuracy: 0.6250
#
# Epoch 00008: val_loss did not improve from 1.00408
# Epoch 9/100
# 27/27 [==============================] - 12s 443ms/step - loss: 0.1087 - accuracy: 0.9761 - val_loss: 1.2460 - val_accuracy: 0.5909
#
# Epoch 00009: val_loss did not improve from 1.00408
# Epoch 10/100
# 27/27 [==============================] - 12s 461ms/step - loss: 0.1341 - accuracy: 0.9489 - val_loss: 1.6036 - val_accuracy: 0.5682
#
# Epoch 00010: val_loss did not improve from 1.00408
# Epoch 11/100
# 27/27 [==============================] - 12s 453ms/step - loss: 0.1144 - accuracy: 0.9647 - val_loss: 1.2959 - val_accuracy: 0.6136
#
# Epoch 00011: val_loss did not improve from 1.00408
# Epoch 12/100
# 27/27 [==============================] - 12s 451ms/step - loss: 0.0691 - accuracy: 0.9912 - val_loss: 1.1002 - val_accuracy: 0.6364
#
# Epoch 00012: val_loss did not improve from 1.00408
# Epoch 13/100
# 27/27 [==============================] - 12s 458ms/step - loss: 0.0443 - accuracy: 0.9940 - val_loss: 1.1479 - val_accuracy: 0.6477
#
# Epoch 00013: val_loss did not improve from 1.00408
# Epoch 14/100
# 27/27 [==============================] - 12s 454ms/step - loss: 0.0551 - accuracy: 0.9882 - val_loss: 1.1007 - val_accuracy: 0.6705
#
# Epoch 00014: val_loss did not improve from 1.00408
# Epoch 15/100
# 27/27 [==============================] - 13s 467ms/step - loss: 0.0581 - accuracy: 0.9860 - val_loss: 1.1896 - val_accuracy: 0.6136
#
# Epoch 00015: val_loss did not improve from 1.00408
# Epoch 16/100
# 27/27 [==============================] - 13s 470ms/step - loss: 0.0441 - accuracy: 0.9902 - val_loss: 1.0097 - val_accuracy: 0.6591
#
# Epoch 00016: val_loss did not improve from 1.00408
# Epoch 17/100
# 27/27 [==============================] - 12s 454ms/step - loss: 0.0387 - accuracy: 0.9891 - val_loss: 0.9503 - val_accuracy: 0.6477
#
# Epoch 00017: val_loss improved from 1.00408 to 0.95035, saving model to lstm_models_n_mfcc0060-val-loss-0017.ckpt
# Epoch 18/100
# 27/27 [==============================] - 14s 504ms/step - loss: 0.0258 - accuracy: 0.9962 - val_loss: 0.8148 - val_accuracy: 0.6818
#
# Epoch 00018: val_loss improved from 0.95035 to 0.81479, saving model to lstm_models_n_mfcc0060-val-loss-0018.ckpt
# Epoch 19/100
# 27/27 [==============================] - 12s 454ms/step - loss: 0.0227 - accuracy: 0.9993 - val_loss: 1.0854 - val_accuracy: 0.6705
#
# Epoch 00019: val_loss did not improve from 0.81479
# Epoch 20/100
# 27/27 [==============================] - 12s 459ms/step - loss: 0.0151 - accuracy: 1.0000 - val_loss: 0.8746 - val_accuracy: 0.6932
#
# Epoch 00020: val_loss did not improve from 0.81479
# Epoch 21/100
# 27/27 [==============================] - 13s 466ms/step - loss: 0.0157 - accuracy: 0.9978 - val_loss: 1.0452 - val_accuracy: 0.6250
#
# Epoch 00021: val_loss did not improve from 0.81479
# Epoch 22/100
# 27/27 [==============================] - 12s 449ms/step - loss: 0.0145 - accuracy: 0.9998 - val_loss: 1.2181 - val_accuracy: 0.6705
#
# Epoch 00022: val_loss did not improve from 0.81479
# Epoch 23/100
# 27/27 [==============================] - 12s 459ms/step - loss: 0.0224 - accuracy: 0.9982 - val_loss: 0.8282 - val_accuracy: 0.7386
#
# Epoch 00023: val_loss did not improve from 0.81479
# Epoch 24/100
# 27/27 [==============================] - 12s 455ms/step - loss: 0.0131 - accuracy: 0.9987 - val_loss: 1.0921 - val_accuracy: 0.6250
#
# Epoch 00024: val_loss did not improve from 0.81479
# Epoch 25/100
# 27/27 [==============================] - 12s 453ms/step - loss: 0.0129 - accuracy: 1.0000 - val_loss: 1.1540 - val_accuracy: 0.6364
#
# Epoch 00025: val_loss did not improve from 0.81479
# Epoch 26/100
# 27/27 [==============================] - 12s 453ms/step - loss: 0.0126 - accuracy: 0.9997 - val_loss: 0.9636 - val_accuracy: 0.7045
#
# Epoch 00026: val_loss did not improve from 0.81479
# Epoch 27/100
# 27/27 [==============================] - 12s 453ms/step - loss: 0.0194 - accuracy: 0.9995 - val_loss: 1.1350 - val_accuracy: 0.6250
#
# Epoch 00027: val_loss did not improve from 0.81479
# Epoch 28/100
# 27/27 [==============================] - 12s 452ms/step - loss: 0.0127 - accuracy: 0.9984 - val_loss: 1.3139 - val_accuracy: 0.5909
#
# Epoch 00028: val_loss did not improve from 0.81479
# Epoch 29/100
# 27/27 [==============================] - 12s 454ms/step - loss: 0.0124 - accuracy: 1.0000 - val_loss: 0.8854 - val_accuracy: 0.6818
#
# Epoch 00029: val_loss did not improve from 0.81479
# Epoch 30/100
# 27/27 [==============================] - 12s 450ms/step - loss: 0.0080 - accuracy: 0.9992 - val_loss: 0.9942 - val_accuracy: 0.6705
#
# Epoch 00030: val_loss did not improve from 0.81479
# Epoch 31/100
# 27/27 [==============================] - 13s 495ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.8332 - val_accuracy: 0.7045
#
# Epoch 00031: val_loss did not improve from 0.81479
# Epoch 32/100
# 27/27 [==============================] - 12s 442ms/step - loss: 0.0063 - accuracy: 0.9997 - val_loss: 1.1655 - val_accuracy: 0.6477
#
# Epoch 00032: val_loss did not improve from 0.81479
# Epoch 33/100
# 27/27 [==============================] - 12s 443ms/step - loss: 0.0115 - accuracy: 1.0000 - val_loss: 1.0775 - val_accuracy: 0.6818
#
# Epoch 00033: val_loss did not improve from 0.81479
# Epoch 34/100
# 27/27 [==============================] - 12s 454ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 1.0668 - val_accuracy: 0.6364
#
# Epoch 00034: val_loss did not improve from 0.81479
# Epoch 35/100
# 27/27 [==============================] - 12s 450ms/step - loss: 0.0083 - accuracy: 0.9986 - val_loss: 0.8222 - val_accuracy: 0.7727
#
# Epoch 00035: val_loss did not improve from 0.81479
# Epoch 36/100
# 27/27 [==============================] - 12s 449ms/step - loss: 0.0123 - accuracy: 0.9952 - val_loss: 1.3446 - val_accuracy: 0.7500
#
# Epoch 00036: val_loss did not improve from 0.81479
# Epoch 37/100
# 27/27 [==============================] - 12s 445ms/step - loss: 0.0102 - accuracy: 0.9973 - val_loss: 1.2468 - val_accuracy: 0.7955
#
# Epoch 00037: val_loss did not improve from 0.81479
# Epoch 38/100
# 27/27 [==============================] - 12s 446ms/step - loss: 0.0055 - accuracy: 0.9998 - val_loss: 1.4653 - val_accuracy: 0.7386
#
# Epoch 00038: val_loss did not improve from 0.81479
# Epoch 39/100
# 27/27 [==============================] - 12s 454ms/step - loss: 0.0093 - accuracy: 0.9989 - val_loss: 1.2274 - val_accuracy: 0.7386
#
# Epoch 00039: val_loss did not improve from 0.81479
# Epoch 40/100
# 27/27 [==============================] - 12s 450ms/step - loss: 0.0055 - accuracy: 0.9998 - val_loss: 1.3463 - val_accuracy: 0.7045
# Epoch 00040: val_loss did not improve from 0.81479
# Epoch 41/100
# 27/27 [==============================] - 12s 446ms/step - loss: 0.0156 - accuracy: 0.9970 - val_loss: 1.0671 - val_accuracy: 0.7159
#
# Epoch 00041: val_loss did not improve from 0.81479
# Epoch 42/100
# 27/27 [==============================] - 12s 446ms/step - loss: 0.0334 - accuracy: 0.9898 - val_loss: 1.5538 - val_accuracy: 0.6932
#
# Epoch 00042: val_loss did not improve from 0.81479
# Epoch 43/100
# 27/27 [==============================] - 13s 476ms/step - loss: 0.0891 - accuracy: 0.9751 - val_loss: 1.7339 - val_accuracy: 0.6591
#
# Epoch 00043: val_loss did not improve from 0.81479
# Epoch 44/100
# 27/27 [==============================] - 13s 467ms/step - loss: 0.0363 - accuracy: 0.9944 - val_loss: 2.1817 - val_accuracy: 0.6591
#
# Epoch 00044: val_loss did not improve from 0.81479
# Epoch 45/100
# 27/27 [==============================] - 12s 455ms/step - loss: 0.0228 - accuracy: 0.9933 - val_loss: 1.6960 - val_accuracy: 0.6477
#
# Epoch 00045: val_loss did not improve from 0.81479
# Epoch 46/100
# 27/27 [==============================] - 12s 455ms/step - loss: 0.0233 - accuracy: 0.9956 - val_loss: 1.9866 - val_accuracy: 0.6023
#
# Epoch 00046: val_loss did not improve from 0.81479
# Epoch 47/100
# 27/27 [==============================] - 12s 456ms/step - loss: 0.1511 - accuracy: 0.9498 - val_loss: 2.0216 - val_accuracy: 0.6023
#
# Epoch 00047: val_loss did not improve from 0.81479
# Epoch 48/100
# 27/27 [==============================] - 12s 448ms/step - loss: 0.0260 - accuracy: 0.9917 - val_loss: 1.2246 - val_accuracy: 0.6932
#
# Epoch 00048: val_loss did not improve from 0.81479
# Epoch 49/100
# 27/27 [==============================] - 12s 463ms/step - loss: 0.0719 - accuracy: 0.9791 - val_loss: 1.9220 - val_accuracy: 0.6591
#
# Epoch 00049: val_loss did not improve from 0.81479
# Epoch 50/100
# 27/27 [==============================] - 12s 450ms/step - loss: 0.0729 - accuracy: 0.9721 - val_loss: 2.4948 - val_accuracy: 0.6136
#
# Epoch 00050: val_loss did not improve from 0.81479
# Epoch 51/100
# 27/27 [==============================] - 12s 449ms/step - loss: 0.0516 - accuracy: 0.9865 - val_loss: 1.6240 - val_accuracy: 0.7045
#
# Epoch 00051: val_loss did not improve from 0.81479
# Epoch 52/100
# 27/27 [==============================] - 12s 458ms/step - loss: 0.0395 - accuracy: 0.9853 - val_loss: 1.3598 - val_accuracy: 0.7045
#
# Epoch 00052: val_loss did not improve from 0.81479
# Epoch 53/100
# 27/27 [==============================] - 12s 449ms/step - loss: 0.0126 - accuracy: 0.9974 - val_loss: 1.6949 - val_accuracy: 0.7614
#
# Epoch 00053: val_loss did not improve from 0.81479
# Epoch 54/100
# 27/27 [==============================] - 13s 465ms/step - loss: 0.0093 - accuracy: 0.9973 - val_loss: 1.5653 - val_accuracy: 0.7614
#
# Epoch 00054: val_loss did not improve from 0.81479
# Epoch 55/100
# 27/27 [==============================] - 12s 460ms/step - loss: 0.0109 - accuracy: 0.9964 - val_loss: 0.6407 - val_accuracy: 0.8295
#
# Epoch 00055: val_loss improved from 0.81479 to 0.64066, saving model to lstm_models_n_mfcc0060-val-loss-0055.ckpt
# Epoch 56/100
# 27/27 [==============================] - 13s 490ms/step - loss: 0.0192 - accuracy: 0.9922 - val_loss: 0.8570 - val_accuracy: 0.7841
#
# Epoch 00056: val_loss did not improve from 0.64066
# Epoch 57/100
# 27/27 [==============================] - 12s 457ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 1.4828 - val_accuracy: 0.6932
#
# Epoch 00057: val_loss did not improve from 0.64066
# Epoch 58/100
# 27/27 [==============================] - 12s 451ms/step - loss: 0.0049 - accuracy: 0.9985 - val_loss: 1.1131 - val_accuracy: 0.7727
#
# Epoch 00058: val_loss did not improve from 0.64066
# Epoch 59/100
# 27/27 [==============================] - 13s 465ms/step - loss: 0.0127 - accuracy: 0.9988 - val_loss: 2.0320 - val_accuracy: 0.7273
#
# Epoch 00059: val_loss did not improve from 0.64066
# Epoch 60/100
# 27/27 [==============================] - 13s 469ms/step - loss: 0.0096 - accuracy: 0.9964 - val_loss: 2.7944 - val_accuracy: 0.6477
#
# Epoch 00060: val_loss did not improve from 0.64066
# Epoch 61/100
# 27/27 [==============================] - 12s 449ms/step - loss: 0.0234 - accuracy: 0.9935 - val_loss: 2.1989 - val_accuracy: 0.6818
#
# Epoch 00061: val_loss did not improve from 0.64066
# Epoch 62/100
# 27/27 [==============================] - 12s 462ms/step - loss: 0.0159 - accuracy: 0.9910 - val_loss: 1.9461 - val_accuracy: 0.7159
#
# Epoch 00062: val_loss did not improve from 0.64066
# Epoch 63/100
# 27/27 [==============================] - 12s 458ms/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 1.6720 - val_accuracy: 0.7273
#
# Epoch 00063: val_loss did not improve from 0.64066
# Epoch 64/100
# 27/27 [==============================] - 13s 466ms/step - loss: 0.0057 - accuracy: 0.9991 - val_loss: 1.9522 - val_accuracy: 0.7727
#
# Epoch 00064: val_loss did not improve from 0.64066
# Epoch 65/100
# 27/27 [==============================] - 13s 469ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 1.2270 - val_accuracy: 0.7955
#
# Epoch 00065: val_loss did not improve from 0.64066
# Epoch 66/100
# 27/27 [==============================] - 12s 457ms/step - loss: 0.0055 - accuracy: 0.9996 - val_loss: 1.5856 - val_accuracy: 0.8182
#
# Epoch 00066: val_loss did not improve from 0.64066
# Epoch 67/100
# 27/27 [==============================] - 12s 464ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 1.7878 - val_accuracy: 0.7727
#
# Epoch 00067: val_loss did not improve from 0.64066
# Epoch 68/100
# 27/27 [==============================] - 14s 508ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 1.8402 - val_accuracy: 0.7841
#
# Epoch 00068: val_loss did not improve from 0.64066
# Epoch 69/100
# 27/27 [==============================] - 14s 515ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 1.7589 - val_accuracy: 0.7841
#
# Epoch 00069: val_loss did not improve from 0.64066
# Epoch 70/100
# 27/27 [==============================] - 12s 458ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.9007 - val_accuracy: 0.7727
#
# Epoch 00070: val_loss did not improve from 0.64066
# Epoch 71/100
# 27/27 [==============================] - 12s 455ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.7518 - val_accuracy: 0.7841
#
# Epoch 00071: val_loss did not improve from 0.64066
# Epoch 72/100
# 27/27 [==============================] - 12s 449ms/step - loss: 0.0050 - accuracy: 0.9980 - val_loss: 1.5340 - val_accuracy: 0.8068
#
# Epoch 00072: val_loss did not improve from 0.64066
# Epoch 73/100
# 27/27 [==============================] - 13s 463ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.3804 - val_accuracy: 0.8295
#
# Epoch 00073: val_loss did not improve from 0.64066
# Epoch 74/100
# 27/27 [==============================] - 12s 454ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.5670 - val_accuracy: 0.7841
#
# Epoch 00074: val_loss did not improve from 0.64066
# Epoch 75/100
# 27/27 [==============================] - 12s 458ms/step - loss: 6.6344e-04 - accuracy: 1.0000 - val_loss: 1.6285 - val_accuracy: 0.8182
#
# Epoch 00075: val_loss did not improve from 0.64066
# Epoch 76/100
# 27/27 [==============================] - 12s 455ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.6151 - val_accuracy: 0.7727
#
# Epoch 00076: val_loss did not improve from 0.64066
# Epoch 77/100
# 27/27 [==============================] - 12s 451ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.7235 - val_accuracy: 0.7727
#
# Epoch 00077: val_loss did not improve from 0.64066
# Epoch 78/100
# 27/27 [==============================] - 12s 455ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.4074 - val_accuracy: 0.7841
#
# Epoch 00078: val_loss did not improve from 0.64066
# Epoch 79/100
# 27/27 [==============================] - 12s 454ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 2.0920 - val_accuracy: 0.7386
#
# Epoch 00079: val_loss did not improve from 0.64066
# Epoch 80/100
# 27/27 [==============================] - 12s 453ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 1.2960 - val_accuracy: 0.7727
#
# Epoch 00080: val_loss did not improve from 0.64066
# Epoch 81/100
# 27/27 [==============================] - 13s 478ms/step - loss: 8.8600e-04 - accuracy: 1.0000 - val_loss: 1.8370 - val_accuracy: 0.7386
#
# Epoch 00081: val_loss did not improve from 0.64066
# Epoch 82/100
# 27/27 [==============================] - 12s 452ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 1.1761 - val_accuracy: 0.7955
#
# Epoch 00082: val_loss did not improve from 0.64066
# Epoch 83/100
# 27/27 [==============================] - 13s 466ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.5206 - val_accuracy: 0.7841
#
# Epoch 00083: val_loss did not improve from 0.64066
# Epoch 84/100
# 27/27 [==============================] - 12s 449ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.3960 - val_accuracy: 0.7841
#
# Epoch 00084: val_loss did not improve from 0.64066
# Epoch 85/100
# 27/27 [==============================] - 12s 447ms/step - loss: 5.2028e-04 - accuracy: 1.0000 - val_loss: 1.4197 - val_accuracy: 0.7727
#
# Epoch 00085: val_loss did not improve from 0.64066
# Epoch 86/100
# 27/27 [==============================] - 12s 459ms/step - loss: 6.5373e-04 - accuracy: 1.0000 - val_loss: 1.5068 - val_accuracy: 0.7841
#
# Epoch 00086: val_loss did not improve from 0.64066
# Epoch 87/100
# 27/27 [==============================] - 12s 451ms/step - loss: 7.6255e-04 - accuracy: 1.0000 - val_loss: 1.5235 - val_accuracy: 0.7841
#
# Epoch 00087: val_loss did not improve from 0.64066
# Epoch 88/100
# 27/27 [==============================] - 12s 458ms/step - loss: 4.2686e-04 - accuracy: 1.0000 - val_loss: 1.4938 - val_accuracy: 0.7841
#
# Epoch 00088: val_loss did not improve from 0.64066
# Epoch 89/100
# 27/27 [==============================] - 12s 448ms/step - loss: 3.8945e-04 - accuracy: 1.0000 - val_loss: 1.5472 - val_accuracy: 0.7841
#
# Epoch 00089: val_loss did not improve from 0.64066
# Epoch 90/100
# 27/27 [==============================] - 12s 452ms/step - loss: 4.0806e-04 - accuracy: 1.0000 - val_loss: 1.5350 - val_accuracy: 0.7841
#
# Epoch 00090: val_loss did not improve from 0.64066
# Epoch 91/100
# 27/27 [==============================] - 12s 451ms/step - loss: 5.5496e-04 - accuracy: 1.0000 - val_loss: 1.4524 - val_accuracy: 0.7841
#
# Epoch 00091: val_loss did not improve from 0.64066
# Epoch 92/100
# 27/27 [==============================] - 12s 451ms/step - loss: 4.1703e-04 - accuracy: 1.0000 - val_loss: 1.4571 - val_accuracy: 0.7955
#
# Epoch 00092: val_loss did not improve from 0.64066
# Epoch 93/100
# 27/27 [==============================] - 12s 459ms/step - loss: 5.0794e-04 - accuracy: 1.0000 - val_loss: 1.5967 - val_accuracy: 0.7841
#
# Epoch 00093: val_loss did not improve from 0.64066
# Epoch 94/100
# 27/27 [==============================] - 13s 494ms/step - loss: 7.4766e-04 - accuracy: 1.0000 - val_loss: 1.6005 - val_accuracy: 0.7841
#
# Epoch 00094: val_loss did not improve from 0.64066
# Epoch 95/100
# 27/27 [==============================] - 12s 457ms/step - loss: 3.6671e-04 - accuracy: 1.0000 - val_loss: 1.6980 - val_accuracy: 0.7955
#
# Epoch 00095: val_loss did not improve from 0.64066
# Epoch 96/100
# 27/27 [==============================] - 12s 453ms/step - loss: 4.2875e-04 - accuracy: 1.0000 - val_loss: 1.7271 - val_accuracy: 0.7955
#
# Epoch 00096: val_loss did not improve from 0.64066
# Epoch 97/100
# 27/27 [==============================] - 12s 454ms/step - loss: 3.7250e-04 - accuracy: 1.0000 - val_loss: 1.7435 - val_accuracy: 0.7955
#
# Epoch 00097: val_loss did not improve from 0.64066
# Epoch 98/100
# 27/27 [==============================] - 12s 452ms/step - loss: 5.2444e-04 - accuracy: 1.0000 - val_loss: 1.4974 - val_accuracy: 0.7955
#
# Epoch 00098: val_loss did not improve from 0.64066
# Epoch 99/100
# 27/27 [==============================] - 12s 458ms/step - loss: 3.2479e-04 - accuracy: 1.0000 - val_loss: 1.5510 - val_accuracy: 0.7955
#
# Epoch 00099: val_loss did not improve from 0.64066
# Epoch 100/100
# 27/27 [==============================] - 12s 452ms/step - loss: 2.2982e-04 - accuracy: 1.0000 - val_loss: 1.5675 - val_accuracy: 0.7841
#
# Epoch 00100: val_loss did not improve from 0.64066

# %%
loss, accuracy = model.evaluate(X_test, Y_test)
# Out:
# 3/3 [==============================] - 0s 147ms/step - loss: 1.7800 - accuracy: 0.7841

# %% [markdown]
# Load best model based on val_loss

# %%
latest = tf.train.latest_checkpoint(checkpoint_dir_loss)
model.load_weights(latest)

# %%
loss, accuracy = model.evaluate(X_test, Y_test)
# Out:
# 3/3 [==============================] - 0s 139ms/step - loss: 1.2997 - accuracy: 0.7500
